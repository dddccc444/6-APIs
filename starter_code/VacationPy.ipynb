# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
g_key = ""

gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_cities = pd.read_csv("cities.csv")
weather_cities.head()
# Out:
#    Unnamed: 0            City    Lat     lng  Max Temp  Humidity  Cloudiness  \
# 0           0         rikitea -23.12 -134.97     76.86        65          53
# 1           1          bytosh  53.82   34.09     36.66        74          88
# 2           2     tuktoyaktuk  69.45 -133.04     14.00        85          90
# 3           3  fereydun kenar  36.69   52.52     51.80        87          40
# 4           4          bethel  41.37  -73.41     48.99        33           1
#
#    Wind Speed Country        Date
# 0        5.21      PF  1587144180
# 1        6.67      RU  1587144180
# 2        6.93      CA  1587144181
# 3        2.24      IR  1587144181
# 4       14.99      US  1587144181

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations = weather_cities[["Lat", "lng"]]

# Fill NaN values and convert to float
humdity_location = weather_cities["Humidity"]

# %%
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humdity_location, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=5)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
vacation_df = weather_cities.loc[(weather_cities["Max Temp"] < 80) & (weather_cities["Max Temp"] > 70) \
                             & (weather_cities["Wind Speed"]< 10) & (weather_cities["Cloudiness"] == 0)]

# %%
vacation_df
# Out:
#      Unnamed: 0        City    Lat    lng  Max Temp  Humidity  Cloudiness  \
# 147         147  dera bugti  29.03  69.15     78.31        29           0
#
#      Wind Speed Country        Date
# 147        5.06      PK  1587144143

# %%
vacation_df2 = weather_cities.loc[(weather_cities["Max Temp"] < 80) & (weather_cities["Max Temp"] > 70) \
                             & (weather_cities["Wind Speed"]< 10) & (weather_cities["Cloudiness"] < 5)] 
vacation_df2
# Out:
#      Unnamed: 0                City    Lat     lng  Max Temp  Humidity  \
# 97           97                buin -33.73  -70.75     77.00        33
# 113         113          statesboro  32.45  -81.78     73.40        43
# 147         147          dera bugti  29.03   69.15     78.31        29
# 309         309              beloha -25.17   45.05     74.88        62
# 349         349             dolores -36.31  -57.68     71.92        40
# 390         390              tucson  32.22 -110.93     77.00        16
# 471         471        richards bay -28.78   32.04     71.35        75
# 503         503            chiredzi -21.05   31.67     74.23        71
# 548         548  sulzbach-rosenberg  49.50   11.75     73.00        37
#
#      Cloudiness  Wind Speed Country        Date
# 97            3        4.70      CL  1587144187
# 113           1        9.17      US  1587144188
# 147           0        5.06      PK  1587144143
# 309           2        6.44      MG  1587144172
# 349           4        6.98      AR  1587144203
# 390           1        4.70      US  1587143908
# 471           2        9.57      ZA  1587144211
# 503           4        9.75      ZW  1587144213
# 548           1        5.82      DE  1587144117

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = vacation_df2.loc[:, ["City", "Lat", "lng", "Country"]] 
hotel_df
# Out:
#                    City    Lat     lng Country
# 97                 buin -33.73  -70.75      CL
# 113          statesboro  32.45  -81.78      US
# 147          dera bugti  29.03   69.15      PK
# 309              beloha -25.17   45.05      MG
# 349             dolores -36.31  -57.68      AR
# 390              tucson  32.22 -110.93      US
# 471        richards bay -28.78   32.04      ZA
# 503            chiredzi -21.05   31.67      ZW
# 548  sulzbach-rosenberg  49.50   11.75      DE

# %%
hotel_df["Hotel Name"] = ""

# %%
hotel_df
# Out:
#                    City    Lat     lng Country Hotel Name
# 97                 buin -33.73  -70.75      CL
# 113          statesboro  32.45  -81.78      US
# 147          dera bugti  29.03   69.15      PK
# 309              beloha -25.17   45.05      MG
# 349             dolores -36.31  -57.68      AR
# 390              tucson  32.22 -110.93      US
# 471        richards bay -28.78   32.04      ZA
# 503            chiredzi -21.05   31.67      ZW
# 548  sulzbach-rosenberg  49.50   11.75      DE

# %%
name_address
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAANtUoh455fZ7xPtmX7ojJarB4eH-bvX8ei2Iyb_K-U1WSlOZYJbWGitjqrpKQ0yIxc3iRpzETHgiqOPfHEz15xfLtQM8h94axKa3tdgJlcyBKYYOSAh72sKHgcYzGUKTg9s3jxPBWDC1DDquY0_i9RCqubTdO7dRCmQypruMwdFKxscQd1hFxvGjzYaHleQ-8w1IcqIK1Noc2jiYbx2tLdlaoilmvpaDieTUKodWqlWjhvv9UTdwiIrrXr8dHXaVMyVXTrsFasLQQjj6XEMmX3COf2a4W6hoq7Bedrab-H_m7q7w9cmXfDw64AXd4IuM-JB5JpoUld9SBnfuoU_iTWqZtlc5ssReHwlh-hZhMErlK1gtt1UEaTJVb0C1MICSdRIQ5XOL8T-FW1nGTPUj4E2NkBoUuOz-ypHFHwJVXYuwCVA2zMh1AT4',
#  'results': [{'geometry': {'location': {'lat': 49.5042589, 'lng': 11.7409574},
#     'viewport': {'northeast': {'lat': 49.5056894302915,
#       'lng': 11.7423654302915},
#      'southwest': {'lat': 49.5029914697085, 'lng': 11.7396674697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '2aea898409b89b3ec333c0b75337902026a40a2b',
#    'name': 'Brauereigasthof Flair-Hotel Sperber-Bräu',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1609,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113907253338527875562">Brauereigasthof Flair-Hotel Sperber-Bräu</a>'],
#      'photo_reference': 'CmRaAAAAH46_aLc7yONB9-mVsCN2B3PJv5WrKUf1War96LAe7EkLWIPFPfQMajf6q8ciZ3v62dDJTjPjMNX2JpwBVb_S-8AIisa8mPSjTU2lo2hY8nfx1dUPag2zWOzUZ-5gigwaEhDUASKiiPlGNy8KvqC2VjcXGhSrf2j38ZfKl8k0-RuMZKnX9Mrhuw',
#      'width': 1958}],
#    'place_id': 'ChIJibFeI4LUoUcRxUFsn6ZLWRc',
#    'plus_code': {'compound_code': 'GP3R+P9 Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGP3R+P9'},
#    'rating': 4.2,
#    'reference': 'ChIJibFeI4LUoUcRxUFsn6ZLWRc',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 138,
#    'vicinity': 'Rosenberger Straße 14, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.506856, 'lng': 11.706151},
#     'viewport': {'northeast': {'lat': 49.5082437302915,
#       'lng': 11.7075032802915},
#      'southwest': {'lat': 49.5055457697085, 'lng': 11.7048053197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '10485a9f3de4e10dfe43cd19ddca924db57abd50',
#    'name': 'Gasthof zum Wulfen',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112874910310730943741">Alex Klex</a>'],
#      'photo_reference': 'CmRaAAAANaoa6LL5nL_tlcBBPMrr3Mht-Oqwm7qk9OsKoSomDtD7MerK1BHz8P7VIhABqKtmEENZiUHhfWcoQsK38n5901Zj8ULaKvtww1OiIlplPz5CPRIKhMh5UwVOP6qC2EmcEhCaUciCrhwKUW5qX7vBjAl6GhS4sTmnOHoto2Za_v0t8hDdWHPXoQ',
#      'width': 4032}],
#    'place_id': 'ChIJZaQ9-wnUoUcRWp02Xdmy6f4',
#    'plus_code': {'compound_code': 'GP44+PF Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGP44+PF'},
#    'rating': 4.5,
#    'reference': 'ChIJZaQ9-wnUoUcRWp02Xdmy6f4',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 291,
#    'vicinity': 'Neukirchner Weg 1, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.486042, 'lng': 11.751699},
#     'viewport': {'northeast': {'lat': 49.4874579802915,
#       'lng': 11.7529961802915},
#      'southwest': {'lat': 49.4847600197085, 'lng': 11.7502982197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '0ef82f40084cc89b9b132616b86066181b3df64c',
#    'name': 'Gasthaus Zu den sieben Quellen',
#    'photos': [{'height': 1000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104525668417060769021">Gasthaus Zu den sieben Quellen</a>'],
#      'photo_reference': 'CmRaAAAAC_9Cupn5aC6TaBvHKLMN8-kBKzaE2wlxcss-_w0YNGtD2wZRz7mX3s76CxKw0l8bEb68dUyU_L8MnnipXN4Mn3-YPBHyTXuskG8piz9wS2nfLZxGJ0TLTX5rj0pyW7N2EhBwCub32lNOcKYbWqQog6_RGhRnfbLXgHzTd4z_m5iD4-zh34b02Q',
#      'width': 1000}],
#    'place_id': 'ChIJIwDK65PUoUcRyQ7Jo4r6vBQ',
#    'plus_code': {'compound_code': 'FQP2+CM Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHFQP2+CM'},
#    'rating': 4.2,
#    'reference': 'ChIJIwDK65PUoUcRyQ7Jo4r6vBQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 127,
#    'vicinity': 'OT Breitenbrunn, Rieglesbrunnenstraße 31, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.50595020000001, 'lng': 11.7428385},
#     'viewport': {'northeast': {'lat': 49.5072701302915,
#       'lng': 11.7442178802915},
#      'southwest': {'lat': 49.50457216970851, 'lng': 11.7415199197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '718ded09257a477e912702df2bf814cedceb7a2a',
#    'name': 'Haus Ronja',
#    'place_id': 'ChIJ0YRVoH_ToUcRpi6qtIg7IDk',
#    'plus_code': {'compound_code': 'GP4V+94 Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGP4V+94'},
#    'rating': 4.5,
#    'reference': 'ChIJ0YRVoH_ToUcRpi6qtIg7IDk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Lange Gasse 23, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.5000431, 'lng': 11.7321603},
#     'viewport': {'northeast': {'lat': 49.5012906302915,
#       'lng': 11.7335053302915},
#      'southwest': {'lat': 49.4985926697085, 'lng': 11.7308073697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '2da8b4e2d3c39d80cbe6976f5afc5b2ecbe42f49',
#    'name': 'Haus Blumenau',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 375,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114807342286148066326">Haus Blumenau</a>'],
#      'photo_reference': 'CmRaAAAAerdfD2KQX_Jy1r4uU8Ne3VbVwdfPD4DzpRf1SdM4cGQjJvAvQ7Wytr5-RNvGyn8CxLf1oa9FGp7lOqyoRwpGt70YRd_ZSWF_4T7Ow22uYi90n_zyJzLhBFUPnIChW_nVEhBe48iSrZB9NFUVmBBRAZsSGhTIA-0x_o8GWOJkC_eoTdpwagDDkg',
#      'width': 500}],
#    'place_id': 'ChIJx0DKr37UoUcRNgMHtvEDenk',
#    'plus_code': {'compound_code': 'GP2J+2V Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGP2J+2V'},
#    'rating': 4.4,
#    'reference': 'ChIJx0DKr37UoUcRNgMHtvEDenk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': 'Sandbühl 12, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.4903565, 'lng': 11.7699981},
#     'viewport': {'northeast': {'lat': 49.4916987802915,
#       'lng': 11.7713814302915},
#      'southwest': {'lat': 49.4890008197085, 'lng': 11.7686834697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'c7258d25fef2b7a9fa4a453ee43b8634dfdac665',
#    'name': 'Haus Elias',
#    'photos': [{'height': 998,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111116559475613135788">Haus Elias</a>'],
#      'photo_reference': 'CmRaAAAARhy_OY4pSkW_F3b2pXEOyGCWV1e-UHkIt_XMUnvsoLOXcfc7ZqGGPe5OX2ynV520xEC7Ub6M8ehnOsr5yzBOg3nF3LjcBjusGXvUT9-e9K16sIZIS2SUBe2icUrhOmPtEhAkMDutzu26c73hT0iST5ZMGhQIqvw6ZxsFkNdkQd_aAjuUsQiNZg',
#      'width': 1500}],
#    'place_id': 'ChIJTaOmTLvUoUcRF3G3jjG2pi8',
#    'plus_code': {'compound_code': 'FQR9+4X Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHFQR9+4X'},
#    'rating': 5,
#    'reference': 'ChIJTaOmTLvUoUcRF3G3jjG2pi8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Mittelweg 6, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.46852459999999, 'lng': 11.7254059},
#     'viewport': {'northeast': {'lat': 49.4699304302915,
#       'lng': 11.7267598802915},
#      'southwest': {'lat': 49.4672324697085, 'lng': 11.7240619197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '9cf202167351b4fe089a537d14a5009b3e0872dc',
#    'name': 'Gasthaus Sörgel',
#    'photos': [{'height': 1068,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110689850162243297587">Lars Kienle</a>'],
#      'photo_reference': 'CmRaAAAAcehMozZ3-TMInvOz5JT-TUJeCZqhU-9_mNTbGXX7n9VvDCZCTcbDtbpP55JkUnshN9CiZrc5siHOAqX70bToXYGhV-bPbd3nsa7zdvppxjbVG-PXcircOMaxauRsu3AREhAqL5yJ-R8l2V7SJl8vf6mNGhTwrAjx_WpqxxtH4sue1uXLcBbb8w',
#      'width': 1600}],
#    'place_id': 'ChIJmYN1am-fDEERAtKX065i9bc',
#    'plus_code': {'compound_code': 'FP9G+C5 Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHFP9G+C5'},
#    'rating': 4.7,
#    'reference': 'ChIJmYN1am-fDEERAtKX065i9bc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 41,
#    'vicinity': 'Prohof 1/2, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.48009, 'lng': 11.79708},
#     'viewport': {'northeast': {'lat': 49.4814370302915,
#       'lng': 11.7983251302915},
#      'southwest': {'lat': 49.4787390697085, 'lng': 11.7956271697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '75de71a9bdea81c4cb72ef23828a596d651fdc2d',
#    'name': 'Ferienwohnung Bayer-Wendl ****',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 463,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118387778924817012430">Ferienwohnung Bayer-Wendl ****</a>'],
#      'photo_reference': 'CmRaAAAAXAjXeq7BwpWl2X35ovTk4P3pB2XMsqT0kT8BHWHExCUiY2EmE-GjmPez7zJclMOIau8DyMbnoP2JkErawTtNwXGusSFSC42EjYUwdEShGWlD_JQBfERRVLP9bcVASiIzEhDiyi4B19QobxicDJv_HBi2GhRZiq3v7QfqbkzuLDvbclfgQ5n4YQ',
#      'width': 698}],
#    'place_id': 'ChIJaaQyi0groEcRxlScEDtJ928',
#    'plus_code': {'compound_code': 'FQJW+2R Poppenricht, Germany',
#     'global_code': '8FXHFQJW+2R'},
#    'rating': 5,
#    'reference': 'ChIJaaQyi0groEcRxlScEDtJ928',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'Ohmstraße 4, Poppenricht'},
#   {'geometry': {'location': {'lat': 49.5077472, 'lng': 11.734019},
#     'viewport': {'northeast': {'lat': 49.5090925302915,
#       'lng': 11.7352868302915},
#      'southwest': {'lat': 49.5063945697085, 'lng': 11.7325888697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '52a67c5822238fa9fe7ce673866120a1b97c83f3',
#    'name': 'Ferienwohnung in Lazise am Gardasee',
#    'place_id': 'ChIJP82Vz4bToUcRhkG8cCphON0',
#    'plus_code': {'compound_code': 'GP5M+3J Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGP5M+3J'},
#    'reference': 'ChIJP82Vz4bToUcRhkG8cCphON0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Lerchenfeldstraße 22, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.52020099999999, 'lng': 11.8096014},
#     'viewport': {'northeast': {'lat': 49.52153293029149,
#       'lng': 11.8108865802915},
#      'southwest': {'lat': 49.51883496970849, 'lng': 11.8081886197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '92b7deae25a3e140f845c700733a1bd992da48ea',
#    'name': 'Ferienwohnungen Schuller',
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104212287780225263679">Ferienwohnungen Schuller</a>'],
#      'photo_reference': 'CmRaAAAARLVq1Mx1vCQkvw77cWAn58ONoyPcbasyeCQKPveRlWyLnYXZXHeA8xQUEKRSwvwzYXEP8v9V11dnpiUv3TtmZE3T-TgETWA1wGFzh2o-LJ2q8XYuGv1eoCRT7cMr985mEhBA4biog7_-XGP_jTc38EBNGhQI-86Rlju64GQAoBKxBtcjmLQRUw',
#      'width': 3264}],
#    'place_id': 'ChIJ55kEGH2hDEERJz1n4zSXPWY',
#    'plus_code': {'compound_code': 'GRC5+3R Hahnbach, Germany',
#     'global_code': '8FXHGRC5+3R'},
#    'rating': 5,
#    'reference': 'ChIJ55kEGH2hDEERJz1n4zSXPWY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Kümmersbuch 6, Hahnbach'},
#   {'geometry': {'location': {'lat': 49.5050621, 'lng': 11.7373896},
#     'viewport': {'northeast': {'lat': 49.50642898029149,
#       'lng': 11.7388638302915},
#      'southwest': {'lat': 49.50373101970849, 'lng': 11.7361658697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'ac0021a373d8a2ad6239c1ef23c4fa2be955cda2',
#    'name': 'the Hotel Bayerischer Hof',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1732,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102516704300744710998">Hotelgasthof Bayerischer Hof</a>'],
#      'photo_reference': 'CmRaAAAAd9ixaSOwNrg-TZTyAqAPEGHpFK20wiTujgVhU467v4BJML2OMtpz-e_aaY-z7ABcEkC4TRJ9-_u3C0-6AXeMLK35sr5LvszVsb9_Jde-pjDUT8UHATWn8JexICJNCgB9EhB4Xh11lgTV_FUGYGDrYjhOGhTH6ZsPWmnN7hAo456smZkS4IVACA',
#      'width': 2622}],
#    'place_id': 'ChIJy29MaIDToUcRBBd0zI8ZqwM',
#    'plus_code': {'compound_code': 'GP4P+2X Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGP4P+2X'},
#    'rating': 4,
#    'reference': 'ChIJy29MaIDToUcRBBd0zI8ZqwM',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 154,
#    'vicinity': 'Luitpoldplatz 15 / 17, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.5168823, 'lng': 11.7469346},
#     'viewport': {'northeast': {'lat': 49.51827583029149,
#       'lng': 11.7481703302915},
#      'southwest': {'lat': 49.51557786970849, 'lng': 11.7454723697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'fc3ccf6797718873a8820528e69fd4acd6463801',
#    'name': 'Hotel-Gasthof "Zum Bartl"',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 300,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106474847598293776070">Hotel-Gasthof &quot;Zum Bartl&quot;</a>'],
#      'photo_reference': 'CmRaAAAAw0PucVmN8ErBhZMoXMjzY0Leb9484ckZ8FXR8Nje1ftHNACyJad11ENeReuAGwpMtdByvroLVq0slPqER3yXRAz2qUjuPGMara6qDTzu4nESce8urS7F0a2bALE-3fZ_EhAFrnxNCD88jHsEnY9KS6-bGhQNgDqzFbbUK3V3_K8MufpT4amWcA',
#      'width': 400}],
#    'place_id': 'ChIJPaMQG3bToUcRvGscWQHqbnQ',
#    'plus_code': {'compound_code': 'GP8W+QQ Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGP8W+QQ'},
#    'rating': 4.1,
#    'reference': 'ChIJPaMQG3bToUcRvGscWQHqbnQ',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 35,
#    'vicinity': 'Glückaufstraße 2, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.5004582, 'lng': 11.7564141},
#     'viewport': {'northeast': {'lat': 49.5018543302915,
#       'lng': 11.7578016302915},
#      'southwest': {'lat': 49.4991563697085, 'lng': 11.7551036697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'aca93dc13e5a0e6d5df3b132487542c58abbf5bb',
#    'name': 'Ferienwohnung / Zimmer Meidenbauer',
#    'photos': [{'height': 375,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108408556893643107282">Ferienwohnung / Zimmer Meidenbauer</a>'],
#      'photo_reference': 'CmRaAAAATL7zbpuctRiKcx6af_qKRBZqnaHkXzj2vUktsYVM9mgq5I5gCPxSKJJHeYyEjY7o7AY5rMcsSRkLfa_8FSnxyyeTUxZOxSLhHCH7912MgU8i4wGwEZqvABtqs3zW9K-YEhCqXZo_Hqzz3ypuwtd7_hXNGhTA-CmIQvSN_7iZFDRSKJAuxP4vxw',
#      'width': 500}],
#    'place_id': 'ChIJT2FlpJ3UoUcR1642OpOvDHg',
#    'plus_code': {'compound_code': 'GQ24+5H Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGQ24+5H'},
#    'rating': 4.8,
#    'reference': 'ChIJT2FlpJ3UoUcR1642OpOvDHg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'Dr.-Martin-Luther-Straße 18, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.50403910000001, 'lng': 11.7421196},
#     'viewport': {'northeast': {'lat': 49.5054176802915,
#       'lng': 11.7434892802915},
#      'southwest': {'lat': 49.5027197197085, 'lng': 11.7407913197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '75d0919bb5057470f111372fd3cc45500f4e2fc0',
#    'name': 'Suche Ro',
#    'place_id': 'ChIJza5c3H_ToUcRf2zZqrpmNPg',
#    'plus_code': {'compound_code': 'GP3R+JR Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGP3R+JR'},
#    'reference': 'ChIJza5c3H_ToUcRf2zZqrpmNPg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Rosenberger Straße 26, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.50407889999999, 'lng': 11.7351507},
#     'viewport': {'northeast': {'lat': 49.50544688029149,
#       'lng': 11.7367182802915},
#      'southwest': {'lat': 49.5027489197085, 'lng': 11.7340203197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '9e6ff7451bda0d5a4437ad2b0e858bc846d2c79b',
#    'name': 'Wohnen Im Turm',
#    'photos': [{'height': 3036,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100585392485229548793">Mark Manguno</a>'],
#      'photo_reference': 'CmRaAAAAaAZ8n2UEfRpbMYmucLrTyBpzW8YnRbEZfT3PQMBE0T_61J6Az0MOqZX2GUe6KH466buCi-6DzboCYE5cTGMNZWvDicE9kXlX1TtmB5xDFPKGTQR_cS7eiWYbvsL0gMxwEhBjsoz-THeuqyHbDaCpPyrWGhScpoi2fNH88K35dqQd9D09AmaTHA',
#      'width': 4048}],
#    'place_id': 'ChIJpy7hYH_UoUcRx_krc3pOiEU',
#    'plus_code': {'compound_code': 'GP3P+J3 Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGP3P+J3'},
#    'rating': 4.7,
#    'reference': 'ChIJpy7hYH_UoUcRx_krc3pOiEU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Obere Bachgasse 35A, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.49396000000001, 'lng': 11.76566},
#     'viewport': {'northeast': {'lat': 49.4951737302915,
#       'lng': 11.7669960802915},
#      'southwest': {'lat': 49.49247576970851, 'lng': 11.7642981197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '3e7ede35831622df0676b157ffc77aac6a08a88d',
#    'name': 'Ferienwohnung TINOsHOME',
#    'photos': [{'height': 497,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102324515234329448471">Ferienwohnung TINOsHOME</a>'],
#      'photo_reference': 'CmRaAAAAY0E1QbsTgcZMYAcmJJ14a6al7w2_nU27PmWmARDnM_ec4b7UtQyMH9BlnbCR3cjEn9eBTEYOyGJp2tGuIVMBChgjHXxixWdDQ8VTefTvi_XTI7CP2k0Iz7Yd4r0CobL6EhAtxcc0P1y2EfBmADXom4xSGhSsFRV8FhaeCsowv3bEEyBc4BWNYg',
#      'width': 1022}],
#    'place_id': 'ChIJ11whgtbVoUcRfVbx1oGyprg',
#    'plus_code': {'compound_code': 'FQV8+H7 Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHFQV8+H7'},
#    'rating': 5,
#    'reference': 'ChIJ11whgtbVoUcRfVbx1oGyprg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Schlesierstraße 9, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.49307, 'lng': 11.76558},
#     'viewport': {'northeast': {'lat': 49.4943089302915,
#       'lng': 11.7668482302915},
#      'southwest': {'lat': 49.4916109697085, 'lng': 11.7641502697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '3fd0efe6d1ccf93f311031739180b020f8f93b01',
#    'name': 'Armin & Melanie Scharping Ferienwohnungvermietung',
#    'place_id': 'ChIJT9sJ-qLUoUcRRFK_-cbAgjE',
#    'plus_code': {'compound_code': 'FQV8+66 Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHFQV8+66'},
#    'rating': 5,
#    'reference': 'ChIJT9sJ-qLUoUcRRFK_-cbAgjE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Hugo-Geiger-Straße 55 A, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.50674, 'lng': 11.73392},
#     'viewport': {'northeast': {'lat': 49.5083068302915,
#       'lng': 11.7351609302915},
#      'southwest': {'lat': 49.5056088697085, 'lng': 11.7324629697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'd6da0002e684cb43b8082baa99460eefdc288bf7',
#    'name': 'Klein Haus 12A',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117180600017062813628">Klein Haus 12A</a>'],
#      'photo_reference': 'CmRaAAAAZcR2-InP3ojnRAw7a051kwEzAPmXRP_dNPt1Wxa9e0a4PHBsPYVHPOfBuUM-0M-Tnp8ZdP2WUf4db2uWUp0oIDaq5cCS1zsgB54DrF-cxds6pcOzTjJM0MxAijAhaS4NEhB_-ReptQAP6cMZdtjNKegXGhTxVVLM2P1G12_Cu1tMH-JDp3G0TA',
#      'width': 3264}],
#    'place_id': 'ChIJn0Fg5EnToUcRpfN3K3jebpQ',
#    'plus_code': {'compound_code': 'GP4M+MH Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHGP4M+MH'},
#    'reference': 'ChIJn0Fg5EnToUcRpfN3K3jebpQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Lerchenfeldstraße 12A, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.4898414, 'lng': 11.7722206},
#     'viewport': {'northeast': {'lat': 49.4913485302915,
#       'lng': 11.7734904802915},
#      'southwest': {'lat': 49.4886505697085, 'lng': 11.7707925197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '8183433b7144e5ba11cfd2ac2812e9af344a4ccc',
#    'name': 'Gästehaus "Sandra"',
#    'photos': [{'height': 667,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108554627176698745889">Gästehaus &quot;Sandra&quot;</a>'],
#      'photo_reference': 'CmRaAAAAH3IihUYBPbB0P9KdFgR_cEmqQGjPJEHdX3yw27E7hmgYyafoWenvglevzJPgw1VsOG3kGEU5MzBR3FD8u66zxtn8NaGfjqcDY3h6k01ecVc80z-a7Fx0nKcaCkUAPLZFEhAgLsNgK7wf9zGgJHJPq54sGhRytOXqswE7qhfBWsm4YpV976zjoA',
#      'width': 1000}],
#    'place_id': 'ChIJp_en1rrUoUcR2X8MjycZQKw',
#    'plus_code': {'compound_code': 'FQQC+WV Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHFQQC+WV'},
#    'rating': 3.8,
#    'reference': 'ChIJp_en1rrUoUcR2X8MjycZQKw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 53,
#    'vicinity': 'Rosenbachstraße 10, Sulzbach-Rosenberg'},
#   {'geometry': {'location': {'lat': 49.47451, 'lng': 11.74185},
#     'viewport': {'northeast': {'lat': 49.4759838802915,
#       'lng': 11.7429951302915},
#      'southwest': {'lat': 49.4732859197085, 'lng': 11.7402971697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'b26539d48a9b3647d4bd4a0dbb97b83ed2f5deb3',
#    'name': 'Forrest-Ground-Ranch',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJn_Vu55bVoUcRL7bfJP-UKww',
#    'plus_code': {'compound_code': 'FPFR+RP Sulzbach-Rosenberg, Germany',
#     'global_code': '8FXHFPFR+RP'},
#    'rating': 5,
#    'reference': 'ChIJn_Vu55bVoUcRL7bfJP-UKww',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Grund 6, Sulzbach-Rosenberg'}],
#  'status': 'OK'}

# %%
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key
}

for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["lng"]
    params["location"] = f"{lat},{lng}"
    # Use the search term: "Hotel" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # make request and print url
    name_address = requests.get(base_url, params=params)
    # convert to json
    name_address = name_address.json()
    # Grab the first hotel from the results and store the name
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
hotel_df
# Out:
# Missing field/result... skipping.
#                    City    Lat     lng Country  \
# 97                 buin -33.73  -70.75      CL
# 113          statesboro  32.45  -81.78      US
# 147          dera bugti  29.03   69.15      PK
# 309              beloha -25.17   45.05      MG
# 349             dolores -36.31  -57.68      AR
# 390              tucson  32.22 -110.93      US
# 471        richards bay -28.78   32.04      ZA
# 503            chiredzi -21.05   31.67      ZW
# 548  sulzbach-rosenberg  49.50   11.75      DE
#
#                                         Hotel Name
# 97                                         Paihuen
# 113         Holiday Inn Statesboro-University Area
# 147               SARDAR GHULAM MUSTAFA KHAN BUGTI
# 309
# 349                          Apart Hotel - Arianos
# 390  DoubleTree by Hilton Hotel Tucson - Reid Park
# 471              BON Hotel Waterfront Richards Bay
# 503                               The Nesbitt Arms
# 548       Brauereigasthof Flair-Hotel Sperber-Bräu

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "lng"]]

# %%
# Add marker layer ontop of heat map

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
